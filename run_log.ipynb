# %%
# can simply run this command. Recommend
# !python run_log.py
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# from agents.random.submission import my_controller as m0
# from agents.random.submission import my_controller as m1
# step0
# [[array([103.39993], dtype=float32), array([20.14982], dtype=float32)], [array([191.98918], dtype=float32), array([-1.028819], dtype=float32)]]
# [[array([-23.471172], dtype=float32), array([-14.427856], dtype=float32)], [array([113.37428], dtype=float32), array([21.149973], dtype=float32)]]
# [[array([53.208004], dtype=float32), array([24.749514], dtype=float32)], [array([123.110344], dtype=float32), array([-2.6488307], dtype=float32)]]
# [[array([52.299805], dtype=float32), array([9.552677], dtype=float32)], [array([42.91374], dtype=float32), array([11.425793], dtype=float32)]]
# [[array([121.579735], dtype=float32), array([4.398463], dtype=float32)], [array([-40.02675], dtype=float32), array([-17.334135], dtype=float32)]]
# [[array([117.45216], dtype=float32), array([4.3460975], dtype=float32)], [array([-84.6475], dtype=float32), array([-23.884327], dtype=float32)]]
# [[array([188.17906], dtype=float32), array([14.489524], dtype=float32)], [array([-51.316223], dtype=float32), array([15.211544], dtype=float32)]]
# [[array([141.75089], dtype=float32), array([-17.907604], dtype=float32)], [array([-22.531929], dtype=float32), array([8.058489], dtype=float32)]]
# [[array([-60.842007], dtype=float32), array([-26.684177], dtype=float32)], [array([-21.127546], dtype=float32), array([-20.033152], dtype=float32)]]
# [[array([193.06345], dtype=float32), array([-5.1526556], dtype=float32)], [array([124.54883], dtype=float32), array([18.606037], dtype=float32)]]
# step10
# [[array([115.04898], dtype=float32), array([21.61307], dtype=float32)], [array([169.52875], dtype=float32), array([-18.36578], dtype=float32)]]
# [[array([169.32686], dtype=float32), array([15.879915], dtype=float32)], [array([29.178421], dtype=float32), array([6.979089], dtype=float32)]]
# [[array([73.77123], dtype=float32), array([9.921696], dtype=float32)], [array([197.72592], dtype=float32), array([-25.9071], dtype=float32)]]
# [[array([36.49921], dtype=float32), array([3.9147327], dtype=float32)], [array([-68.16033], dtype=float32), array([5.1782184], dtype=float32)]]
# [[array([128.28624], dtype=float32), array([-24.020155], dtype=float32)], [array([83.37369], dtype=float32), array([-8.911712], dtype=float32)]]
# [[array([-17.902592], dtype=float32), array([16.977007], dtype=float32)], [array([5.0002236], dtype=float32), array([-10.729758], dtype=float32)]]
# [[array([188.88307], dtype=float32), array([-9.43558], dtype=float32)], [array([-20.254934], dtype=float32), array([-1.8770075], dtype=float32)]]
# [[array([147.39604], dtype=float32), array([4.273967], dtype=float32)], [array([0.09745309], dtype=float32), array([-19.466454], dtype=float32)]]
# [[array([101.06822], dtype=float32), array([-25.625044], dtype=float32)], [array([-88.751175], dtype=float32), array([4.7523932], dtype=float32)]]
# [[array([-69.59041], dtype=float32), array([10.727374], dtype=float32)], [array([-47.37505], dtype=float32), array([9.309613], dtype=float32)]]
# step20
# [[array([-78.63398], dtype=float32), array([-11.27275], dtype=float32)], [array([19.119804], dtype=float32), array([-25.967144], dtype=float32)]]
# [[array([-50.462986], dtype=float32), array([2.3090098], dtype=float32)], [array([-7.567106], dtype=float32), array([-26.370548], dtype=float32)]]
# [[array([45.814323], dtype=float32), array([-2.0877607], dtype=float32)], [array([-75.80341], dtype=float32), array([-22.180128], dtype=float32)]]
# [[array([38.479885], dtype=float32), array([5.483715], dtype=float32)], [array([86.555145], dtype=float32), array([7.367704], dtype=float32)]]
# [[array([157.17307], dtype=float32), array([15.086256], dtype=float32)], [array([48.82037], dtype=float32), array([-9.413074], dtype=float32)]]
# [[array([-81.93394], dtype=float32), array([-20.249208], dtype=float32)], [array([111.19465], dtype=float32), array([18.72471], dtype=float32)]]
# [[array([174.03914], dtype=float32), array([-15.852241], dtype=float32)], [array([-48.177666], dtype=float32), array([-16.274176], dtype=float32)]]
# [[array([59.420536], dtype=float32), array([17.243784], dtype=float32)], [array([57.53504], dtype=float32), array([-28.441133], dtype=float32)]]
# [[array([-33.840782], dtype=float32), array([-6.782944], dtype=float32)], [array([-22.579523], dtype=float32), array([18.78042], dtype=float32)]]
# [[array([52.775803], dtype=float32), array([-18.694931], dtype=float32)], [array([-0.4630378], dtype=float32), array([-28.301825], dtype=float32)]]
# step30
# [[array([-50.832867], dtype=float32), array([2.3749757], dtype=float32)], [array([-89.39847], dtype=float32), array([-16.618217], dtype=float32)]]
# [[array([-75.77153], dtype=float32), array([14.714284], dtype=float32)], [array([-27.786114], dtype=float32), array([-26.16425], dtype=float32)]]
# [[array([73.138535], dtype=float32), array([22.886627], dtype=float32)], [array([-78.963234], dtype=float32), array([-0.6586557], dtype=float32)]]
# [[array([59.59609], dtype=float32), array([-5.5330744], dtype=float32)], [array([-31.33751], dtype=float32), array([22.991562], dtype=float32)]]

# %%
# or run the blocks below
import os
import time
import json
import numpy as np
import sys
import pygame

sys.path.append("./olympics_engine")

from env.chooseenv import make
from utils.get_logger import get_logger
from env.obs_interfaces.observation import obs_type


class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)


def get_players_and_action_space_list(g):
    if sum(g.agent_nums) != g.n_player:
        raise Exception("agent number = %d 不正确，与n_player = %d 不匹配" % (sum(g.agent_nums), g.n_player))

    n_agent_num = list(g.agent_nums)
    for i in range(1, len(n_agent_num)):
        n_agent_num[i] += n_agent_num[i - 1]

    # 根据agent number 分配 player id
    players_id = []
    actions_space = []
    for policy_i in range(len(g.obs_type)):
        if policy_i == 0:
            players_id_list = range(n_agent_num[policy_i])
        else:
            players_id_list = range(n_agent_num[policy_i - 1], n_agent_num[policy_i])
        players_id.append(players_id_list)

        action_space_list = [g.get_single_action_space(player_id) for player_id in players_id_list]
        actions_space.append(action_space_list)

    return players_id, actions_space


def get_joint_action_eval(game, multi_part_agent_ids, policy_list, actions_spaces, all_observes):
    if len(policy_list) != len(game.agent_nums):
        error = "模型个数%d与玩家个数%d维度不正确！" % (len(policy_list), len(game.agent_nums))
        raise Exception(error)

    # [[[0, 0, 0, 1]], [[0, 1, 0, 0]]]
    joint_action = []
    for policy_i in range(len(policy_list)):

        if game.obs_type[policy_i] not in obs_type:
            raise Exception("可选obs类型：%s" % str(obs_type))

        agents_id_list = multi_part_agent_ids[policy_i]

        action_space_list = actions_spaces[policy_i]
        function_name = 'm%d' % policy_i
        for i in range(len(agents_id_list)):
            agent_id = agents_id_list[i]
            a_obs = all_observes[agent_id]
            each = eval(function_name)(a_obs, action_space_list[i], game.is_act_continuous)
            game.is_single_valid_action(each, action_space_list[i], policy_i)
            joint_action.append(each)
    print(joint_action)
    return joint_action


def set_seed(g, env_name):
    if env_name.split("-")[0] in ['magent']:
        g.reset()
        seed = g.create_seed()
        g.set_seed(seed)


def run_game(g, env_name, multi_part_agent_ids, actions_spaces, policy_list, render_mode):
    """
    This function is used to generate log for Vue rendering. Saves .json file
    """
    log_path = os.getcwd() + '/logs/'
    if not os.path.exists(log_path):
        os.mkdir(log_path)

    logger = get_logger(log_path, g.game_name, json_file=render_mode)
    set_seed(g, env_name)

    for i in range(len(policy_list)):
        if policy_list[i] not in get_valid_agents():
            raise Exception("agent {} not valid!".format(policy_list[i]))

        file_path = os.path.join(os.getcwd(), "agents", policy_list[i], "submission.py")
        if not os.path.exists(file_path):
            raise Exception("file {} not exist!".format(file_path))

        # import_path = '.'.join(file_path.split('/')[-3:])[:-3]
        import_path = '.'.join(['agents', policy_list[i], 'submission'])
        function_name = 'm%d' % i
        import_name = "my_controller"
        import_s = "from %s import %s as %s" % (import_path, import_name, function_name)
        print(import_s)
        exec(import_s, globals())

    st = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time()))
    game_info = {"game_name": env_name,
                 "n_player": g.n_player,
                 "board_height": g.board_height if hasattr(g, "board_height") else None,
                 "board_width": g.board_width if hasattr(g, "board_width") else None,
                 "init_info": g.init_info,
                 "start_time": st,
                 "mode": "terminal",
                 "seed": g.seed if hasattr(g, "seed") else None,
                 "map_size": g.map_size if hasattr(g, "map_size") else None}

    steps = []
    all_observes = g.all_observes
    while not g.is_terminal():
        step = "step%d" % g.step_cnt
        if g.step_cnt % 10 == 0:
            print(step)

        if render_mode and hasattr(g, "env_core"):
            if hasattr(g.env_core, "render"):
                g.env_core.render()
        info_dict = {"time": time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time()))}
        joint_act = get_joint_action_eval(g, multi_part_agent_ids, policy_list, actions_spaces, all_observes)
        all_observes, reward, done, info_before, info_after = g.step(joint_act)
        if env_name.split("-")[0] in ["magent"]:
            info_dict["joint_action"] = g.decode(joint_act)
        if info_before:
            info_dict["info_before"] = info_before
        info_dict["reward"] = reward
        if info_after:
            info_dict["info_after"] = info_after
        steps.append(info_dict)

    game_info["steps"] = steps
    game_info["winner"] = g.check_win()
    game_info["winner_information"] = g.won
    game_info["n_return"] = g.n_return
    ed = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time()))
    game_info["end_time"] = ed
    logs = json.dumps(game_info, ensure_ascii=False, cls=NpEncoder)
    logger.info(logs)


def get_valid_agents():
    dir_path = os.path.join(os.getcwd(), 'agents')
    return [f for f in os.listdir(dir_path) if f != "__pycache__"]
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
env_type = "olympics-wrestling"
game = make(env_type, seed=None)

render_mode = True

# policy_list = ["random"] * len(game.agent_nums)
policy_list = ["random", "random"] # your policy, the folder name under agents

multi_part_agent_ids, actions_space = get_players_and_action_space_list(game)

run_game(game, env_type, multi_part_agent_ids, actions_space, policy_list, render_mode)
pygame.quit()
# Out:
# from agents.random.submission import my_controller as m0
# from agents.random.submission import my_controller as m1
# step0
# [[array([129.1693], dtype=float32), array([29.711187], dtype=float32)], [array([18.770868], dtype=float32), array([5.283855], dtype=float32)]]
# [[array([150.79143], dtype=float32), array([20.12188], dtype=float32)], [array([119.04926], dtype=float32), array([-4.659135], dtype=float32)]]
# [[array([-61.504528], dtype=float32), array([-17.620546], dtype=float32)], [array([-90.61181], dtype=float32), array([29.53458], dtype=float32)]]
# [[array([-10.639216], dtype=float32), array([4.2851415], dtype=float32)], [array([133.55753], dtype=float32), array([3.9955542], dtype=float32)]]
# [[array([133.51227], dtype=float32), array([-26.343813], dtype=float32)], [array([35.412], dtype=float32), array([12.715875], dtype=float32)]]
# [[array([1.3118306], dtype=float32), array([-26.600008], dtype=float32)], [array([-19.744585], dtype=float32), array([-12.073001], dtype=float32)]]
# [[array([152.81822], dtype=float32), array([-2.3207455], dtype=float32)], [array([159.36084], dtype=float32), array([-24.899847], dtype=float32)]]
# [[array([133.12398], dtype=float32), array([13.907952], dtype=float32)], [array([-40.826946], dtype=float32), array([3.457341], dtype=float32)]]
# [[array([111.481865], dtype=float32), array([4.7872148], dtype=float32)], [array([69.0675], dtype=float32), array([8.346159], dtype=float32)]]
# [[array([57.278744], dtype=float32), array([-0.42128667], dtype=float32)], [array([160.66017], dtype=float32), array([-11.166217], dtype=float32)]]
# step10
# [[array([26.457785], dtype=float32), array([-13.940859], dtype=float32)], [array([84.67585], dtype=float32), array([-8.857743], dtype=float32)]]
# [[array([-32.873466], dtype=float32), array([-21.093605], dtype=float32)], [array([173.33662], dtype=float32), array([-4.211402], dtype=float32)]]
# [[array([164.57251], dtype=float32), array([-9.949865], dtype=float32)], [array([80.53105], dtype=float32), array([-3.2161374], dtype=float32)]]
# [[array([22.113625], dtype=float32), array([28.856688], dtype=float32)], [array([1.5220723], dtype=float32), array([-9.367433], dtype=float32)]]
# [[array([-40.025303], dtype=float32), array([-21.974377], dtype=float32)], [array([68.54969], dtype=float32), array([11.825896], dtype=float32)]]
# [[array([20.687347], dtype=float32), array([-18.54136], dtype=float32)], [array([77.45598], dtype=float32), array([10.256278], dtype=float32)]]
# [[array([-53.210552], dtype=float32), array([-4.498153], dtype=float32)], [array([190.35085], dtype=float32), array([-22.978138], dtype=float32)]]
# [[array([-10.103489], dtype=float32), array([-1.3731971], dtype=float32)], [array([50.438805], dtype=float32), array([6.1239376], dtype=float32)]]
# [[array([-75.56742], dtype=float32), array([22.637844], dtype=float32)], [array([99.972336], dtype=float32), array([-1.9559529], dtype=float32)]]
# [[array([-81.71724], dtype=float32), array([3.7506726], dtype=float32)], [array([-76.967896], dtype=float32), array([10.880491], dtype=float32)]]
# step20
# [[array([90.47011], dtype=float32), array([8.638418], dtype=float32)], [array([-1.831084], dtype=float32), array([-29.093405], dtype=float32)]]
# [[array([72.88613], dtype=float32), array([14.612201], dtype=float32)], [array([137.3986], dtype=float32), array([-2.9676433], dtype=float32)]]
# [[array([-67.23165], dtype=float32), array([-24.044548], dtype=float32)], [array([76.08753], dtype=float32), array([17.117714], dtype=float32)]]
# [[array([70.780396], dtype=float32), array([7.3601108], dtype=float32)], [array([179.39319], dtype=float32), array([-26.339487], dtype=float32)]]
# [[array([33.32592], dtype=float32), array([-22.469282], dtype=float32)], [array([25.430052], dtype=float32), array([16.937876], dtype=float32)]]
# [[array([-29.385359], dtype=float32), array([-5.864536], dtype=float32)], [array([-13.028125], dtype=float32), array([6.7574253], dtype=float32)]]
# [[array([14.889786], dtype=float32), array([-10.278712], dtype=float32)], [array([114.221436], dtype=float32), array([14.060084], dtype=float32)]]
# [[array([190.09933], dtype=float32), array([-19.42999], dtype=float32)], [array([87.03369], dtype=float32), array([-20.258648], dtype=float32)]]
# [[array([148.83058], dtype=float32), array([-12.897861], dtype=float32)], [array([99.84875], dtype=float32), array([-8.745717], dtype=float32)]]
# [[array([153.89647], dtype=float32), array([-22.25566], dtype=float32)], [array([-77.05656], dtype=float32), array([-25.750109], dtype=float32)]]
# step30
# [[array([130.3368], dtype=float32), array([17.578833], dtype=float32)], [array([-18.88937], dtype=float32), array([29.800894], dtype=float32)]]
# [[array([77.942566], dtype=float32), array([-27.092789], dtype=float32)], [array([-59.491405], dtype=float32), array([-29.070635], dtype=float32)]]
# [[array([127.91408], dtype=float32), array([24.834526], dtype=float32)], [array([18.830614], dtype=float32), array([7.57546], dtype=float32)]]
# [[array([49.182827], dtype=float32), array([22.895233], dtype=float32)], [array([-31.328302], dtype=float32), array([12.0935545], dtype=float32)]]
# [[array([79.21396], dtype=float32), array([-8.605167], dtype=float32)], [array([166.63991], dtype=float32), array([7.028871], dtype=float32)]]
# [[array([157.36053], dtype=float32), array([-11.867094], dtype=float32)], [array([-88.00892], dtype=float32), array([-27.917349], dtype=float32)]]
# [[array([132.75562], dtype=float32), array([-13.091804], dtype=float32)], [array([154.86508], dtype=float32), array([4.9243255], dtype=float32)]]
# [[array([-49.944527], dtype=float32), array([22.034395], dtype=float32)], [array([36.283695], dtype=float32), array([-19.344625], dtype=float32)]]
# [[array([103.701866], dtype=float32), array([8.328677], dtype=float32)], [array([12.676851], dtype=float32), array([-14.420917], dtype=float32)]]
# [[array([162.86104], dtype=float32), array([-25.98831], dtype=float32)], [array([61.682884], dtype=float32), array([-10.552611], dtype=float32)]]
# step40
# [[array([85.21412], dtype=float32), array([27.710293], dtype=float32)], [array([-43.40376], dtype=float32), array([23.183083], dtype=float32)]]
# [[array([88.401184], dtype=float32), array([29.281334], dtype=float32)], [array([-49.276604], dtype=float32), array([-24.535543], dtype=float32)]]
# [[array([119.70617], dtype=float32), array([-8.225682], dtype=float32)], [array([104.226654], dtype=float32), array([-15.259383], dtype=float32)]]
